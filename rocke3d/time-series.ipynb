# %%
import os

# Set the base directory (in case you want to
# keep a notebook in a subfolder)
subdir = ''
basedir = os.environ['PWD'] + subdir

os.chdir(basedir)

# %%
# External package imports
import matplotlib
import matplotlib.pyplot as plt

# Local package imports
from libs.GcmData.GcmDataLoaderRocke3d import GcmDataLoaderRocke3d
import libs.utils

# Adjust font size of plots with this
# matplotlib.rcParams.update({ 'font.size': 16 })

# %% [markdown]
# ## Data

# %%
# Skip loading the vertical atmosphere variables for speed
loader = GcmDataLoaderRocke3d(
    id='g2v__t1e__450ma',
    path='../../models/rocke3d/huge_space/{id}/ANN*.aij{id}.nc',
    # path_vert={
    #     'aijk': '../../models/rocke3d/huge_space/{id}/ANN*.aijk{id}.nc',
    #     'aijl': '../../models/rocke3d/huge_space/{id}/ANN*.aijl{id}.nc',
    # }
    keep_vars=[]
)

# Load the data, returning an xarray Dataset
gcm_data = loader.load()
# Out:
# Extracting vertical data
# Warning: no vertical data found
# Centering longitude
# Standardising vars

# %% [markdown]
# ## Plotting

# %%
# Select a surface variable, e.g. surface temperature `tas`.
# Remembering that each grid cell is a different size,
# we need to take a weighted mean before we plot:
gcm_data.gcm_utils\
    .weighted_lat()\
    .mean(('lat', 'lon'))\
    ['tas']\
    .plot()

# %%
# Alternatively, we can find a global total value, such as
# precipitation `pr`
gcm_data.gcm_utils\
    .weighted_lat()\
    .sum(('lat', 'lon'))\
    ['pr']\
    .plot()

# %%
# We can also use the create_figure utility function
# to create our own figure and plot to that:

# Create matplotlib figure with axes
fig, axs = libs.utils.create_figure(
    shape=(1, 1), # Figure with 1x1 subfigures
    height=5,     # Subfigure has height of '5'
    width=5       # Subfigure has width of 5
)

gcm_time_series = gcm_data.gcm_utils\
    .weighted_lat()\
    .mean(('lat', 'lon'))\
    ['tas']

gcm_time_series.plot(ax=axs[0])

# %%
# Compare time series of different longitudes average over latitude

# Create matplotlib figure with axes
fig, axs = libs.utils.create_figure(
    shape=(1, 1), # Figure with 1x1 subfigures
    height=5,     # Subfigure has height of '5'
    width=5       # Subfigure has width of 5
)

confs_longitudes = [-180, -90, 0, 90]

# Loop over list of longitudes
for i, lon in enumerate(confs_longitudes):
    gcm_lon_time_series = gcm_data\
        .gcm_utils.weighted_lat()\
        .mean('lat')\
        .sel(lon=lon, method='nearest')\
        ['tas']

    gcm_lon_time_series.plot(
        ax=axs[0],
        label=f'lon={lon}'
    )

# Show legend
axs[0].legend()
